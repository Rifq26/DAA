# %%
aList = ["John", 33, "Toronto", True]
print(aList)
# Out:
# ['John', 33, 'Toronto', True]

# %%
Mahasiswa = ["Rifqi Muhammad", 2020071014,"INF", "DAA", "15/9/2021","UPJ"]
print(Mahasiswa)
# Out:
# ['Rifqi Muhammad', 2020071014, 'INF', 'DAA', '15/9/2021', 'UPJ']

# %%
bin_color= ['Red','Green','Blue','Yellow']
bin_color[1]
# Out:
# 'Green'

# %%
Mahasiswa[1]
# Out:
# 2020071014

# %%
Mahasiswa[5]
# Out:
# 'UPJ'

# %%
bin_color[0:4]
# Out:
# ['Red', 'Green', 'Blue', 'Yellow']

# %%
Mahasiswa[0:6]
# Out:
# ['Rifqi Muhammad', 2020071014, 'INF', 'DAA', '15/9/2021', 'UPJ']

# %%
bin_color1= ['Red','Green','Blue','Yellow']
for aColor in bin_color1:
    print( aColor + "Square" )
# Out:
# RedSquare
# GreenSquare
# BlueSquare
# YellowSquare

# %%
Mahasiswa1 = ["Rifqi", "Salwa", "Rehan", "Wilskuy"]
for aMahasiswa in Mahasiswa1:
    print("UPJ."+ aMahasiswa )
# Out:
# UPJ.Rifqi
# UPJ.Salwa
# UPJ.Rehan
# UPJ.Wilskuy

# %%
bin_colors = ('White','Green','Blue','Yellow')
bin_colors [1]
# Out:
# 'Green'

# %%
bin_colors[2:]
# Out:
# ('Blue', 'Yellow')

# %%
UPJ = ("universitas","pembangunan","Jaya")
print(UPJ)
# Out:
# ('universitas', 'pembangunan', 'Jaya')

# %%
nested_tuple = (100,(200,400,600),300,(400,800))
nested_tuple
# Out:
# (100, (200, 400, 600), 300, (400, 800))

# %%
nested_tuple [0]
# Out:
# 100

# %%
nested_tuple [1]
# Out:
# (200, 400, 600)

# %%
nested_tuple [2]
# Out:
# 300

# %%
nested_tuple [3]
# Out:
# (400, 800)

# %%
bin_colors = {"manual_color":"Yellow", "approved_color":"Green","refused_color":"Red"}
print(bin_colors)
# Out:
# {'manual_color': 'Yellow', 'approved_color': 'Green', 'refused_color': 'Red'}

# %%
bin_colors.get('manual_color')
# Out:
# 'Yellow'

# %%
bin_colors['approved_color']
# Out:
# 'Green'

# %%
bin_colors['approved_color']='Purple'
print(bin_colors)
# Out:
# {'manual_color': 'Yellow', 'approved_color': 'Purple', 'refused_color': 'Red'}

# %%
biodata ={"Nama":"Rifqi Muhammad","NIM":2020071014,"Prodi":"Informatika","Universitas":"UPJ"}
print(biodata)
# Out:
# {'Nama': 'Rifqi Muhammad', 'NIM': 2020071014, 'Prodi': 'Informatika', 'Universitas': 'UPJ'}

# %%
biodata.get('Nama')
# Out:
# 'Rifqi Muhammad'

# %%
biodata['Prodi']
# Out:
# 'Informatika'

# %%
Green = {'Grass','Leaves'}
print(Green)
# Out:
# {'Leaves', 'Grass'}

# %%
Green = {'Grass','Leaves','Leaves','Grass'}
print(Green)
# Out:
# {'Leaves', 'Grass'}

# %%
yellow = {'dandelions', 'leaves', 'fire hydrant'}
red = {'rose','blood','leaves','fire hydrant' }

yellow|red
# Out:
# {'blood', 'dandelions', 'fire hydrant', 'leaves', 'rose'}

# %%
yellow&red
# Out:
# {'fire hydrant', 'leaves'}

# %%
import pandas as pd
df = pd.DataFrame([['1','Fares',32,True],['2','Elena',23,False],['3','Steven',40,True]])

# %%
print(df)
# Out:
#    0       1   2      3
# 0  1   Fares  32   True
# 1  2   Elena  23  False
# 2  3  Steven  40   True

# %%
df
# Out:
#    0       1   2      3
# 0  1   Fares  32   True
# 1  2   Elena  23  False
# 2  3  Steven  40   True

# %%
df[['name','age']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-2f24eab8f8ed> in <module>
# ----> 1 df[['name','age']]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index(['name', 'age'], dtype='object')] are in the [columns]"

# %%
df.iloc[:,3]
# Out:
# 0     True
# 1    False
# 2     True
# Name: 3, dtype: bool

# %%
df.iloc[1:3,:]
# Out:
#    0       1   2      3
# 1  2   Elena  23  False
# 2  3  Steven  40   True

# %%
df[df.age>30]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-ebf2df608c86> in <module>
# ----> 1 df[df.age>30]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'age'

# %%
df[(df.age<35)&(df.decision==True)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-d35df48d8347> in <module>
# ----> 1 df[(df.age<35)&(df.decision==True)]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'age'

# %%
mhs=pd.DataFrame([['Informatika',50,30,20],['Sistem Informasi',55,30,25],['Teknik Sipil', 40,30,10]])

# %%
import numpy as np
myMatrix = np.array([[11, 12, 13], [21, 22, 23], [31, 32, 33]])
print(myMatrix)
# Out:
# [[11 12 13]
#  [21 22 23]
#  [31 32 33]]

# %%
print(type(myMatrix))
# Out:
# <class 'numpy.ndarray'>

# %%
Matrix = np.array([[100, 200, 300], [700, 600, 500], [900, 1000, 800]])
print(Matrix)
# Out:
# [[ 100  200  300]
#  [ 700  600  500]
#  [ 900 1000  800]]

# %%
class Stack:
    def __init__(self):
        self.items = []
    def isEmpty(self):
        return self.items == []
    def push(self, item):
        self.items.append(item)
    def pop(self):
        return self.items.pop()
    def peek(self):
        return self.items[len(self.items)-1]
    def size(self):
        return len(self.items)

# %%
stack = Stack()
stack.push('Red')
stack.push('Green')
stack.push('Blue')
stack.push('Yellow')

# %%
print(stack.pop())
# Out:
# Yellow

# %%
print(stack.isEmpty())
# Out:
# False

# %%
class Queue(object):
    def __init__(self):
        self.items = []
    def isEmpty(self):
        return self.items == []
    def enqueue(self, item):
        self.items.insert(0,item)
    def dequeue(self):
        return self.items.pop()
    def size(self):
        return len(self.items)

# %%
queue =  Queue()
queue.enqueue('Red')
queue.enqueue('Green')
queue.enqueue('Blue')
queue.enqueue('Yellow')
print(queue.size())
# Out:
# 4

# %%
print(queue.dequeue())
# Out:
# Red

# %%
print(queue.dequeue())
# Out:
# Green
