# %%
#swab function
var1 = 1
var2 = 2
var1, var2 = var2, var1
print(var1,var2)
# Out:
# 2 1

# %%
#latihan Buat fungsi swap dengan menambahkan variabel ketiga bernama var3!
var1 = 1
var2 = 2
var3 = 3
var1, var2, var3 = var3, var1, var2
print(var1,var2,var3)
# Out:
# 3 1 2

# %%
#algoritma bubble sort

list = [25,21,22,24,23,27,26]


#proses penukaran bubble sort

lastElementIndex = len(list)-1 #len yaitu kepanjangan dri lenght
print(0,list)
for idx in range(lastElementIndex):
    if list[idx]>list[idx+1]: #apabila idx lebih besar dari pada idx+1 maka proses penukaran dilakukan
        list[idx],list[idx+1]=list[idx+1],list[idx]
    print(idx+1,list)
# Out:
# 0 [25, 21, 22, 24, 23, 27, 26]
# 1 [21, 25, 22, 24, 23, 27, 26]
# 2 [21, 22, 25, 24, 23, 27, 26]
# 3 [21, 22, 24, 25, 23, 27, 26]
# 4 [21, 22, 24, 23, 25, 27, 26]
# 5 [21, 22, 24, 23, 25, 27, 26]
# 6 [21, 22, 24, 23, 25, 26, 27]

# %%
list
# Out:
# [21, 22, 24, 23, 25, 26, 27]

# %%
#algoritma bubble sort Exchange

def BubbleSort(list):
#Exchange the elements to arrange in order
    lastElementIndex = len(list)-1
    for passNo in range(lastElementIndex,0,-1): # 0,-1 berfungsi agar melakukan pengurutan sampai value terurut dengan sempurna 
        for idx in range(passNo):
            if list[idx]>list[idx+1]:
                list[idx],list[idx+1]=list[idx+1],list[idx]
    return list

# %%
#masukan angka dengan urutan lainnya

list = [11,14,15,12,16,13,17,18,19]


#melakukan sorting
BubbleSort(list)
# Out:
# [11, 12, 13, 14, 15, 16, 17, 18, 19]

# %%
#Latihan bubble sort Urutkan deret bilangan di bawah ini menggunakan metode sorting bubble sort!
list = [100,20,60,90,40,30,10]
BubbleSort(list)
# Out:
# [10, 20, 30, 40, 60, 90, 100]

# %%
#Algoritma insertion sort

def InsertionSort(list):
    for i in range(1, len(list)):
        j = i-1
        next = list[i]

# Compare the current element with the one
        while(list[j] > next) and (j >= 0):
            list[j+1] = list[j]
            j = j-1
        list[j+1] = next
    return list

# %%
#masukan angka dengan urutan lainnya

list = [35,31,32,34,33,37,36]

#cetak nilai list sebelum di sorting
list
# Out:
# [35, 31, 32, 34, 33, 37, 36]

# %%
InsertionSort(list)
# Out:
# [31, 32, 33, 34, 35, 36, 37]

# %%
""#Algoritma insertion sort TROUBLESHOOT tanpa deklarasi list[i] menjdi next

def InsertionSort(list):
    for i in range(1, len(list)):
        j = i-1
        #next = list[i]

# Compare the current element with the one
        #while(list[j] > next) and (j >= 0):
        while(list[j] > list[i]) and (j >= 0):
            list[j+1] = list[j]
            j = j-1
        #list[j+1] = next
        list[j+1] = list[i]
    return list
""
# Out:
# ''

# %%
#Latihan InsertionSort, Urutkan deret bilangan di bawah ini menggunakan metode sorting insertion sort!

list = [89,12,57,16,25,11,75]

#cetak nilai setelah di-sorting
InsertionSort(list)
# Out:
# [11, 12, 16, 25, 57, 75, 89]

# %%
#Algoritma Selection Sort

def SelectionSort(list):
    for fill_slot in range(len(list) -1,0,-1):
        max_index = 0
        for location in range(2, fill_slot + 1):
            if list[location] > list[max_index]:
                max_index = location
        list[fill_slot],list[max_index] = list[max_index],list[fill_slot]
    return list

#NOTE -1 yg pertama buat ngambil urutan nilai dari paling blakang trs -1 yg kedua buat ngurangin ururtan jdi ururtan sblm nilai plaing blakang
#Misal total ada 5 ururtan nilai pertamanya 5 trs -1 jdi ururtan ke 4

# %%
#masukan angka dengan urutan acak
list = [70,15,25,19,35,44]

#cetak nilai setelah di-sorting
SelectionSort(list)
# Out:
# [15, 19, 25, 35, 44, 70]

# %%
#Latihan Selection sort, Tentukan prosedur pengurutan deret secara ascending menggunakan metode sorting selection sort!

list = [89,12,57,16,25]

#cetak nilai setelah di-sorting
SelectionSort(list)
# Out:
# [12, 16, 25, 57, 89]

# %%
# Algoritma Linear Search

def LinearSearch(list, item):
    index = 0
    found = False
    
# Match the value with earch with data element
    while index < len(list) and found is False:
        if list[index] == item:
            found = True
        else:
            index = index + 1
    return found

# %%
#masukan angka kedalam list
list = [12,33,11,99,55,90]
print(LinearSearch(list, 12))
print(LinearSearch(list, 91))
# Out:
# True
# False

# %%
# Latihan Linear Search, Cari “a” dari deret huruf di bawah ini menggunakan metode searching linear search!

list = ['y','u','i','w','o','a','q','u','j','p']
print(LinearSearch(list, 'a'))
print(LinearSearch(list, 'q'))
print(LinearSearch(list, 'z'))
# Out:
# True
# True
# False

# %%
# Algoritma Binary Search

def BinarySearch(list, item):
    first = 0
    last = len(list)-1
    found = False
    
    while first <= last and not found:
        midpoint = (first + last)//2 #nilai first + last lalu di bagi 2
        if list[midpoint] == item:
            found = True
        else:
            if item < list[midpoint]:
                last = midpoint-1
            else:
                first = midpoint+1
            
    return found

# NOTE Untuk melakukan floor division dan mendapatkan hasil integer atau bilangan bulat (menghilangkan hasil pecahannya) Anda dapat menggunakan operator //

# >>> 17 / 3  # classic division returns a float
# 5.666666666666667
# >>>
# >>> 17 // 3  # floor division discards the fractional part
# 5

#

# %%
#masukan angka kedalam list
list = [12,33,11,99,22,55,90]

sorted_list = BubbleSort(list)
print(BinarySearch(list, 12))
print(BinarySearch(list, 91))
# Out:
# True
# False

# %%
# Latihan Binary Search, Cari “a” dari deret huruf di bawah ini menggunakan metode searching binary search!

list = ['y','u','i','w','o','a','q','u','j','p']
#sorted_list = BubbleSort(list)
# apabila tidak ada "sorted_list = BubbleSort(list)" maka nilai 'a' FALSE
print(BinarySearch(list, 'a'))
print(BinarySearch(list, 'q'))
# Out:
# False
# True

# %%
# Latihan Binary Search, Cari “a” dari deret huruf di bawah ini menggunakan metode searching binary search!

list = ['y','u','i','w','o','a','q','u','j','p']
sorted_list = BubbleSort(list)
print(BinarySearch(list, 'a'))
print(BinarySearch(list, 'q'))
print(BinarySearch(list, 'z'))
# Out:
# True
# True
# False

# %%
# Algoritma Interpolation Search

def IntPolsearch(list, x):
    idx0 = 0
    idxn = (len(list) -1)
    found = False
    
    while idx0 <= idxn and x >= list[idx0] and x <= list[idxn]:
# Find the mid point
        mid = idx0 + int(((float(idxn - idx0) / (list[idxn] - list[idx0])) * (x - list[idx0])))

# Compare the value at mid point with search value
        if list[mid] == x:
            found = True
            return found
        
        if list[mid] < x:
            idx0 = mid + 1
    return found

# %%
list = [12,33,11,99,22,55,90]

sorted_list = BubbleSort(list)
print(IntPolsearch(list, 12))
print(IntPolsearch(list, 91))
# Out:
# True
# False

# %%
# Latihan Interpolation Search, Cari “u” dari deret huruf di bawah ini menggunakan metode searching interpolation search!

list = ['y','u','i','w','o','a','q','u','j','p']
sorted_list = BubbleSort(list)
print(IntPolsearch(list, 'u'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-51517ea9d3c0> in <module>
#       3 list = ['y','u','i','w','o','a','q','u','j','p']
#       4 sorted_list = BubbleSort(list)
# ----> 5 print(IntPolsearch(list, 'u'))
#
# <ipython-input-112-4275027490c8> in IntPolsearch(list, x)
#       8     while idx0 <= idxn and x >= list[idx0] and x <= list[idxn]:
#       9 # Find the mid point
# ---> 10         mid = idx0 + int(((float(idxn - idx0) / (list[idxn] - list[idx0])) * (x - list[idx0])))
#      11
#      12 # Compare the value at mid point with search value
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
# Latihan Interpolation Search, Cari “u” dari deret huruf di bawah ini menggunakan metode searching interpolation search!

list = [2,0,2,0,0,7,1,0,1,4]
sorted_list = BubbleSort(list)
print(IntPolsearch(list, 0))
# Out:
# True
